# %% [markdown]
# # Imports in Binance

# %%
from binance_client import client
from binance_data import get_balances, get_margin_trades, get_margin_orders
from binance_conversions import get_portfolio_values
from binance_display import to_dataframe, margin_order_list
from binance_graph import btc_5y_graph

import pandas as pd

# %% [markdown]
# # Binance Logic

# %%
balance = get_balances()
balance_gbp = get_portfolio_values(balance)

print(to_dataframe(balance_gbp))
# Out:
#    coin     amount  value_gbp
# 0  ETHW   0.000099        NaN
# 1  USDT  16.680235  14.135793
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
btc_5y_graph()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# trade = get_margin_trades("BTCUSDT")
# print(trade)
#
# list = to_dataframe(trade)
# print(list)

# %%
margin_order_list()
# Out:
#     symbol  side    type     price  origQty executedQty  status  \
# 0  BTCUSDT  SELL  MARKET  72967.17  0.00079     0.00079  FILLED
# 1  BTCUSDT   BUY   LIMIT  72534.96  0.00083     0.00083  FILLED
# 2  BTCUSDT  SELL  MARKET  71054.89  0.00082     0.00082  FILLED
# 3  BTCUSDT   BUY   LIMIT  68737.23  0.00086     0.00086  FILLED
# 4  BTCUSDT  SELL  MARKET  67850.01  0.00095     0.00095  FILLED
# 5  BTCUSDT   BUY   LIMIT  67000.00  0.00095     0.00095  FILLED
# 6  BTCUSDT   BUY   LIMIT  68063.21  0.00008     0.00008  FILLED
#
#                      time
# 0 2026-03-04 17:28:56.508
# 1 2026-03-05 03:02:56.263
# 2 2026-03-05 17:18:33.209
# 3 2026-03-06 14:45:45.248
# 4 2026-03-06 20:34:44.917
# 5 2026-03-07 22:27:23.705
# 6 2026-03-08 10:24:30.376
